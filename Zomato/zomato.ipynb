# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
df = pd.read_csv('Zomato data .csv')

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %% [markdown]
# ##### A Funciont to convert rate to a float.

# %%
def handel_rate(rate):
    value = str(rate).split('/')[0]
    return float(value)

df['rate'] = df['rate'].apply(handel_rate)

df['rate'].head()

# %% [markdown]
# ##### Explore the listed_in (type) column.

# %%
sns.countplot(x=df['listed_in(type)'], hue=df['listed_in(type)'])
plt.xlabel('Type of resturant')
# Out:
# Text(0.5, 0, 'Type of resturant')

# %% [markdown]
# #### *We can conclued that the majority of the restaurants fall into the Dining category.*

# %% [markdown]
# ##### The restaurant’s name that received the maximum votes.

# %%
res_with_max_rates = df.loc[(df['votes'] == df['votes'].max()), 'name']
res_with_max_rates
# Out:
# 38    Empire Restaurant
# Name: name, dtype: object

# %% [markdown]
# ##### Explore the online_order column.

# %%
# Custom color palette 
palette = sns.color_palette("bright", len(df['online_order'].unique()))
sns.countplot(x=df['online_order'], hue = df['online_order'], palette=palette, legend=False)
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %% [markdown]
# ##### *We can conlude that a majority of the restaurants do not accept online orders.*

# %% [markdown]
# ##### Explore the rate column.

# %%
df['rate'].plot(kind='hist', bins=5, title="Ratings Distribution")
# Out:
# <Axes: title={'center': 'Ratings Distribution'}, ylabel='Frequency'>

# %% [markdown]
# ##### *We can conclude that the majority of restaurants received ratings ranging from 3.5 to 4.*

# %% [markdown]
# ##### Explore the approx_cost(for two people) column.

# %%
palette = sns.color_palette("husl", len(df['approx_cost(for two people)'].unique()))
sns.countplot(x=df['approx_cost(for two people)'], hue=df['approx_cost(for two people)'], palette=palette, legend=False)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %% [markdown]
# ##### *The majority of couples prefer restaurants with an approximate cost of 300 rupees.*

# %% [markdown]
# ##### Examine whether online orders receive higher ratings than offline orders.

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(x='online_order', y='rate', hue = 'online_order', data=df, legend=False)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %% [markdown]
# ##### *Offline orders received lower ratings in comparison to online orders, which obtained excellent ratings.*
